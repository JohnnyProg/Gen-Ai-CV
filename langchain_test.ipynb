# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pip install langchain

# %%
# %pip install langchain-google-genai langchain-google-vertexai
# %pip install -U langchain langchain-openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 27.0 MB/s eta 0:00:0031m32.3 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 38.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.45
#     Uninstalling langchain-core-0.3.45:
#       Successfully uninstalled langchain-core-0.3.45
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import config
from langchain_google_genai import ChatGoogleGenerativeAI

os.environ["GOOGLE_API_KEY"] = config.API_TOKEN
os.environ["LANGSMITH_API_KEY"] = config.LANGSMITH_TOKEN
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_ENDPOINT"] = config.LANGSMITH_ENDPOINT
os.environ["LANGSMITH_PROJECT"] = config.LANGSMITH_PROJECT

print(config.LANGSMITH_TOKEN)

llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)
# Out:
# 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

# %%
from src.extract_text import PDFReader
pdfReader = PDFReader()
pdfs = pdfReader.readfiles("./resumes_dataset/resumes_dataset/")
print(pdfs[0])
text = pdfReader.openFile(pdfs[0])
# Out:
# ./resumes_dataset/resumes_dataset/16121387.pdf

# %%
from src.translator import Translator
translator2 = Translator(llm)

res1 = translator2.translate(text)
res1
# Out:
# AIMessage(content='empty', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-826c31cf-fc01-4849-b0e7-64646f14dc17-0', usage_metadata={'input_tokens': 2062, 'output_tokens': 2, 'total_tokens': 2064, 'input_token_details': {'cache_read': 0}})

# %%
from src.EntityExtractor import EntityExtractor

extractor = EntityExtractor(llm)

extraction = extractor.extract(text)
extraction
# Out:
# /home/jgryta/Documents/LLM/src/EntityExtractor.py:88: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = self.llm(messages)
# {'name': None,
#  'job_title': 'Medical Record Technician',
#  'education': [{'degree': 'M.H.A.MASTERS',
#    'field': 'HEALTHCARE ADMINISTRATION',
#    'institution': 'The University of Phoenix'}],
#  'experience': [{'position': 'Medical Record Technician',
#    'company': 'Company Name',
#    'years_of_experience': 11,
#    'technologies_used': [],
#    'responsibilities': 'Analyzes complex data for completeness and accuracy. Distributes and release information in an efficient manner of time in order to improve health outcomes and quality of service.'},
#   {'position': 'HEALTHCARE UNIT COORDINATOR',
#    'company': 'Company Name',
#    'years_of_experience': 2,
#    'technologies_used': [],
# ...
